# %%
from riotwatcher import LolWatcher, ApiError
import pandas as pd
import sys 
import numpy as np
df = pd.read_excel(r'C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Skilled14MinsDataId.xlsx')
df2 = pd.read_excel(r'C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Skilled14MinsDataId1.xlsx')
df_combine = df.append(df2)
print (df_combine)
# Out:
#        Unnamed: 0  blueWins  blueWardsPlaced  blueWardsDestroyed  blueKills  \
# 0               0         1               22                   3          6
# 1               1         1               25                   3         15
# 2               2         1               22                  10         10
# 3               3         1               20                   4         18
# 4               4         1               24                   2          5
# ...           ...       ...              ...                 ...        ...
# 13569       13569         1               73                   4          8
# 13570       13570         0               38                   6         15
# 13571       13571         0               20                   3         12
# 13572       13572         0               20                   5         13
# 13573       13573         0               21                   6         10
#
# ...

# %%
df_combine
# Out:
#        Unnamed: 0  blueWins  blueWardsPlaced  blueWardsDestroyed  blueKills  \
# 0               0         1               22                   3          6
# 1               1         1               25                   3         15
# 2               2         1               22                  10         10
# 3               3         1               20                   4         18
# 4               4         1               24                   2          5
# ...           ...       ...              ...                 ...        ...
# 13569       13569         1               73                   4          8
# 13570       13570         0               38                   6         15
# 13571       13571         0               20                   3         12
# 13572       13572         0               20                   5         13
# 13573       13573         0               21                   6         10
#
# ...

# %%
df_combine.to_excel(excel_writer = "C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Skilled14MinsDataIdFinal.xlsx")

# %%
from riotwatcher import LolWatcher, ApiError
import pandas as pd
import sys 
import numpy as np
df = pd.read_excel(r'C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Average14MinsDataId2.xlsx')
df2 = pd.read_excel(r'C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Average14MinsDataId0.xlsx')
df1 = pd.read_excel(r'C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Average14MinsDataId1.xlsx')
df_combine = df.append(df2)
df_combine2 = df_combine.append(df1)
df_combine2.to_excel(excel_writer = "C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Average14MinsDataIdFinal.xlsx")

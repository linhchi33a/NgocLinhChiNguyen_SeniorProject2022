# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
#'blueWins','blueWardsPlaced','blueWardsDestroyed','blueKills','blueDeaths','blueAssists','blueEliteMonsters','blueDragons','blueHeraldsBarons','blueTowersDestroyed','blueTotalGold','blueTotalDamageToChampions','blueAvgLevel','blueTotalMinionsKilled','blueTotalMinionsKilled','blueGoldDiff'

# %% [markdown]
# ### Correlation for Elite

# %%
dfElite = pd.read_excel(r'C:\Users\linhc\OneDrive\Documents\Sproj\DataCollection\Importantfiles\Elite\Elite14MinsDataIdFiltered.xlsx')
# corr = dfElite.corr()
# corr.style.background_gradient(cmap='coolwarm')

fig , ax = plt.subplots(figsize=(25,25))
ax = sns.heatmap(dfElite.corr(), annot=True ,ax=ax, cmap="YlGnBu",linewidths = .5)
ax.set_title("Correlation Between variables Elite", fontsize=36)
plt.show()

# %% [markdown]
# ### Correlation for Skilled

# %%
dfSkilled = pd.read_excel(r'C:\Users\linhc\OneDrive\Documents\Sproj\DataCollection\Importantfiles\Skilled\Skilled14MinsDataIdFiltered.xlsx')
fig , ax = plt.subplots(figsize=(25,25))
ax = sns.heatmap(dfSkilled.corr(), annot=True ,ax=ax, cmap="YlGnBu",linewidths = .5)
ax.set_title("Correlation Between variables Skilled", fontsize=36)
plt.show()

# %% [markdown]
# ### Correlation for Average

# %%
dfAverage = pd.read_excel(r'C:\Users\linhc\OneDrive\Documents\Sproj\DataCollection\Importantfiles\Average\Average14MinsDataIdFiltered.xlsx')
fig , ax = plt.subplots(figsize=(25,25))
ax = sns.heatmap(dfAverage.corr(), annot=True ,ax=ax, cmap="YlGnBu",linewidths = .5)
ax.set_title("Correlation Between variables Average", fontsize=36)
plt.show()

# %% [markdown]
# ### Correlation for Total of all games

# %%
frames = [dfElite, dfSkilled, dfAverage]
dfTotal= pd.concat(frames)

# %%
corr3 = dfTotal.corr()
corr3.style.background_gradient(cmap='coolwarm')
fig , ax = plt.subplots(figsize=(25,25))
ax = sns.heatmap(dfTotal.corr(), annot=True ,ax=ax, cmap="YlGnBu",linewidths = .5)
ax.set_title("Correlation Between variables - All group", fontsize=36)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import tensorflow as tf
#import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
from sklearn.model_selection import KFold
from tabulate import tabulate

# %% [markdown]
# ### Import Data

# %%
df_Average = pd.read_excel(r'C:\Users\linhc\OneDrive\Documents\Sproj\DataCollection\Importantfiles\TrainingValData\AverageTrainingVal.xlsx')
df_Skilled = pd.read_excel(r'C:\Users\linhc\OneDrive\Documents\Sproj\DataCollection\Importantfiles\TrainingValData\SkilledTrainingVal.xlsx')
df_Elite = pd.read_excel(r'C:\Users\linhc\OneDrive\Documents\Sproj\DataCollection\Importantfiles\TrainingValData\EliteTrainingVal.xlsx')

# %%
df_Elite
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueKills  blueDeaths  \
# 0            0               32                   5         10          15
# 1            1               49                   6         10          14
# 2            1               26                   2         17          10
# 3            1              106                   8         10           8
# 4            1               31                  10         22           7
# ...        ...              ...                 ...        ...         ...
# 8631         1               24                   7          6           7
# 8632         1               20                   8         15           9
# 8633         1               26                   4         17          16
# 8634         1               27                   9          7          13
# 8635         0               20                   4          8          13
#
#       blueAssists  blueEliteMonsters  blueDragons  blueHeraldsBarons  \
# 0              15                  0            0                  0
# 1               6                  1            1                  0
# 2              24                  2            1                  1
# 3              18                  2            1                  1
# 4              24                  3            2                  1
# ...           ...                ...          ...                ...
# 8631            8                  1            1                  0
# 8632           13                  1            1                  0
# 8633           21                  3            2                  1
# 8634           11                  1            1                  0
# 8635            4                  1            0                  1
#
#       blueTowersDestroyed  ...  redEliteMonsters  redDragons  \
# 0                       1  ...                 2           2
# 1                       0  ...                 0           0
# 2                       0  ...                 0           0
# 3                       0  ...                 1           1
# 4                       2  ...                 0           0
# ...                   ...  ...               ...         ...
# 8631                    0  ...                 2           1
# 8632                    1  ...                 1           0
# 8633                    1  ...                 0           0
# 8634                    0  ...                 1           0
# 8635                    0  ...                 1           1
#
#       redHeraldsBarons  redTowersDestroyed  redTotalGold  \
# 0                    0                   1         26016
# 1                    0                   1         25835
# 2                    0                   1         23499
# 3                    0                   0         21625
# 4                    0                   0         21954
# ...                ...                 ...           ...
# 8631                 1                   0         23558
# 8632                 1                   1         24741
# 8633                 0                   0         25491
# 8634                 1                   1         25270
# 8635                 0                   1         28009
#
#       redTotalDamageToChampions  redAvgLevel  redTotalMinionsKilled  \
# 0                         22836          8.4                    279
# 1                         20998          8.6                    301
# 2                         25089          8.6                    268
# 3                         21831          8.4                    297
# 4                         19995          8.4                    293
# ...                         ...          ...                    ...
# 8631                      19954          8.6                    340
# 8632                      23249          8.8                    317
# 8633                      31258          8.6                    246
# 8634                      21193          9.0                    297
# 8635                      24678          9.6                    387
#
#       redTotalJungleMinionsKilled  redGoldDiff
# 0                              69         1063
# 1                              77         3740
# 2                              80        -5804
# 3                              76        -2583
# 4                              79        -9229
# ...                           ...          ...
# 8631                          100          722
# 8632                           79        -1783
# 8633                           62        -2358
# 8634                           68         2430
# 8635                           87         4429
#
# [8636 rows x 31 columns]

# %% [markdown]
# ## Adding and subtract variable

# %%
def addVar(df): 
    df['blue/redAvgLevel'] = round(df['blueAvgLevel']/df['redAvgLevel'],5)
    df['blue/redTotalDamageToChampions'] = round(df['blueTotalDamageToChampions']/df['redTotalDamageToChampions'],5)
    df['red/blueKills'] = round(df['blueKills']/df['redKills'],5)
    df['blueAvgLevel/redAvgLevel'] = round(df['blueAvgLevel']/df['redAvgLevel'],5)
    df = df.drop('redGoldDiff', axis=1)
    return df

# %%
df_Elite = addVar(df_Elite)
df_Average = addVar(df_Average)
df_Skilled = addVar(df_Skilled)
df_Elite
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueKills  blueDeaths  \
# 0            0               32                   5         10          15
# 1            1               49                   6         10          14
# 2            1               26                   2         17          10
# 3            1              106                   8         10           8
# 4            1               31                  10         22           7
# ...        ...              ...                 ...        ...         ...
# 8631         1               24                   7          6           7
# 8632         1               20                   8         15           9
# 8633         1               26                   4         17          16
# 8634         1               27                   9          7          13
# 8635         0               20                   4          8          13
#
#       blueAssists  blueEliteMonsters  blueDragons  blueHeraldsBarons  \
# 0              15                  0            0                  0
# 1               6                  1            1                  0
# 2              24                  2            1                  1
# 3              18                  2            1                  1
# 4              24                  3            2                  1
# ...           ...                ...          ...                ...
# 8631            8                  1            1                  0
# 8632           13                  1            1                  0
# 8633           21                  3            2                  1
# 8634           11                  1            1                  0
# 8635            4                  1            0                  1
#
#       blueTowersDestroyed  ...  redTowersDestroyed  redTotalGold  \
# 0                       1  ...                   1         26016
# 1                       0  ...                   1         25835
# 2                       0  ...                   1         23499
# 3                       0  ...                   0         21625
# 4                       2  ...                   0         21954
# ...                   ...  ...                 ...           ...
# 8631                    0  ...                   0         23558
# 8632                    1  ...                   1         24741
# 8633                    1  ...                   0         25491
# 8634                    0  ...                   1         25270
# 8635                    0  ...                   1         28009
#
#       redTotalDamageToChampions  redAvgLevel  redTotalMinionsKilled  \
# 0                         22836          8.4                    279
# 1                         20998          8.6                    301
# 2                         25089          8.6                    268
# 3                         21831          8.4                    297
# 4                         19995          8.4                    293
# ...                         ...          ...                    ...
# 8631                      19954          8.6                    340
# 8632                      23249          8.8                    317
# 8633                      31258          8.6                    246
# 8634                      21193          9.0                    297
# 8635                      24678          9.6                    387
#
#       redTotalJungleMinionsKilled  blue/redAvgLevel  \
# 0                              69           1.00000
# 1                              77           0.97674
# 2                              80           1.06977
# 3                              76           1.02381
# 4                              79           1.11905
# ...                           ...               ...
# 8631                          100           1.00000
# 8632                           79           1.00000
# 8633                           62           1.00000
# 8634                           68           0.97778
# 8635                           87           0.91667
#
#       blue/redTotalDamageToChampions  red/blueKills  blueAvgLevel/redAvgLevel
# 0                            1.09940        0.66667                   1.00000
# 1                            0.92795        0.71429                   0.97674
# 2                            1.20710        1.70000                   1.06977
# 3                            1.09880        1.25000                   1.02381
# 4                            1.73458        3.14286                   1.11905
# ...                              ...            ...                       ...
# 8631                         0.80946        0.85714                   1.00000
# 8632                         0.96520        1.66667                   1.00000
# 8633                         1.12246        1.06250                   1.00000
# 8634                         1.01321        0.53846                   0.97778
# 8635                         0.65694        0.61538                   0.91667
#
# [8636 rows x 34 columns]

# %%
df_Average.to_excel(excel_writer = "C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Importantfiles/TrainingValData/AverageTrainingValNewVar.xlsx")
df_Skilled.to_excel(excel_writer = "C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Importantfiles/TrainingValData/SkilledTrainingValNewVar.xlsx")
df_Elite.to_excel(excel_writer = "C:/Users/linhc/OneDrive/Documents/Sproj/DataCollection/Importantfiles/TrainingValData/EliteTrainingValNewVar.xlsx")

# %%
df_Average = pd.read_excel(r'C:\Users\linhc\OneDrive\Documents\Sproj\DataCollection\Importantfiles\TrainingValData\AverageTrainingValNewVar.xlsx')
df_Skilled = pd.read_excel(r'C:\Users\linhc\OneDrive\Documents\Sproj\DataCollection\Importantfiles\TrainingValData\SkilledTrainingValNewVar.xlsx')
df_Elite = pd.read_excel(r'C:\Users\linhc\OneDrive\Documents\Sproj\DataCollection\Importantfiles\TrainingValData\EliteTrainingValNewVar.xlsx')

# %%
df_Elite
# Out:
#       Unnamed: 0  blueWins  blueWardsPlaced  blueWardsDestroyed  blueKills  \
# 0              0         0               32                   5         10
# 1              1         1               49                   6         10
# 2              2         1               26                   2         17
# 3              3         1              106                   8         10
# 4              4         1               31                  10         22
# ...          ...       ...              ...                 ...        ...
# 8631        8631         1               24                   7          6
# 8632        8632         1               20                   8         15
# 8633        8633         1               26                   4         17
# 8634        8634         1               27                   9          7
# 8635        8635         0               20                   4          8
#
#       blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# 0             15           15                  0            0
# 1             14            6                  1            1
# 2             10           24                  2            1
# 3              8           18                  2            1
# 4              7           24                  3            2
# ...          ...          ...                ...          ...
# 8631           7            8                  1            1
# 8632           9           13                  1            1
# 8633          16           21                  3            2
# 8634          13           11                  1            1
# 8635          13            4                  1            0
#
#       blueHeraldsBarons  ...  redTowersDestroyed  redTotalGold  \
# 0                     0  ...                   1         26016
# 1                     0  ...                   1         25835
# 2                     1  ...                   1         23499
# 3                     1  ...                   0         21625
# 4                     1  ...                   0         21954
# ...                 ...  ...                 ...           ...
# 8631                  0  ...                   0         23558
# 8632                  0  ...                   1         24741
# 8633                  1  ...                   0         25491
# 8634                  0  ...                   1         25270
# 8635                  1  ...                   1         28009
#
#       redTotalDamageToChampions  redAvgLevel  redTotalMinionsKilled  \
# 0                         22836          8.4                    279
# 1                         20998          8.6                    301
# 2                         25089          8.6                    268
# 3                         21831          8.4                    297
# 4                         19995          8.4                    293
# ...                         ...          ...                    ...
# 8631                      19954          8.6                    340
# 8632                      23249          8.8                    317
# 8633                      31258          8.6                    246
# 8634                      21193          9.0                    297
# 8635                      24678          9.6                    387
#
#       redTotalJungleMinionsKilled  blue/redAvgLevel  \
# 0                              69           1.00000
# 1                              77           0.97674
# 2                              80           1.06977
# 3                              76           1.02381
# 4                              79           1.11905
# ...                           ...               ...
# 8631                          100           1.00000
# 8632                           79           1.00000
# 8633                           62           1.00000
# 8634                           68           0.97778
# 8635                           87           0.91667
#
#       blue/redTotalDamageToChampions  red/blueKills  blueAvgLevel/redAvgLevel
# 0                            1.09940        0.66667                   1.00000
# 1                            0.92795        0.71429                   0.97674
# 2                            1.20710        1.70000                   1.06977
# 3                            1.09880        1.25000                   1.02381
# 4                            1.73458        3.14286                   1.11905
# ...                              ...            ...                       ...
# 8631                         0.80946        0.85714                   1.00000
# 8632                         0.96520        1.66667                   1.00000
# 8633                         1.12246        1.06250                   1.00000
# 8634                         1.01321        0.53846                   0.97778
# 8635                         0.65694        0.61538                   0.91667
#
# [8636 rows x 35 columns]

# %%
#Drop 1st column
df_Elite = df_Elite.iloc[: , 1:]
df_Average = df_Average.iloc[: , 1:]
df_Skilled = df_Skilled.iloc[: , 1:]

# %%
df_Elite
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueKills  blueDeaths  \
# 0            0               32                   5         10          15
# 1            1               49                   6         10          14
# 2            1               26                   2         17          10
# 3            1              106                   8         10           8
# 4            1               31                  10         22           7
# ...        ...              ...                 ...        ...         ...
# 8631         1               24                   7          6           7
# 8632         1               20                   8         15           9
# 8633         1               26                   4         17          16
# 8634         1               27                   9          7          13
# 8635         0               20                   4          8          13
#
#       blueAssists  blueEliteMonsters  blueDragons  blueHeraldsBarons  \
# 0              15                  0            0                  0
# 1               6                  1            1                  0
# 2              24                  2            1                  1
# 3              18                  2            1                  1
# 4              24                  3            2                  1
# ...           ...                ...          ...                ...
# 8631            8                  1            1                  0
# 8632           13                  1            1                  0
# 8633           21                  3            2                  1
# 8634           11                  1            1                  0
# 8635            4                  1            0                  1
#
#       blueTowersDestroyed  ...  redTowersDestroyed  redTotalGold  \
# 0                       1  ...                   1         26016
# 1                       0  ...                   1         25835
# 2                       0  ...                   1         23499
# 3                       0  ...                   0         21625
# 4                       2  ...                   0         21954
# ...                   ...  ...                 ...           ...
# 8631                    0  ...                   0         23558
# 8632                    1  ...                   1         24741
# 8633                    1  ...                   0         25491
# 8634                    0  ...                   1         25270
# 8635                    0  ...                   1         28009
#
#       redTotalDamageToChampions  redAvgLevel  redTotalMinionsKilled  \
# 0                         22836          8.4                    279
# 1                         20998          8.6                    301
# 2                         25089          8.6                    268
# 3                         21831          8.4                    297
# 4                         19995          8.4                    293
# ...                         ...          ...                    ...
# 8631                      19954          8.6                    340
# 8632                      23249          8.8                    317
# 8633                      31258          8.6                    246
# 8634                      21193          9.0                    297
# 8635                      24678          9.6                    387
#
#       redTotalJungleMinionsKilled  blue/redAvgLevel  \
# 0                              69           1.00000
# 1                              77           0.97674
# 2                              80           1.06977
# 3                              76           1.02381
# 4                              79           1.11905
# ...                           ...               ...
# 8631                          100           1.00000
# 8632                           79           1.00000
# 8633                           62           1.00000
# 8634                           68           0.97778
# 8635                           87           0.91667
#
#       blue/redTotalDamageToChampions  red/blueKills  blueAvgLevel/redAvgLevel
# 0                            1.09940        0.66667                   1.00000
# 1                            0.92795        0.71429                   0.97674
# 2                            1.20710        1.70000                   1.06977
# 3                            1.09880        1.25000                   1.02381
# 4                            1.73458        3.14286                   1.11905
# ...                              ...            ...                       ...
# 8631                         0.80946        0.85714                   1.00000
# 8632                         0.96520        1.66667                   1.00000
# 8633                         1.12246        1.06250                   1.00000
# 8634                         1.01321        0.53846                   0.97778
# 8635                         0.65694        0.61538                   0.91667
#
# [8636 rows x 34 columns]

# %% [markdown]
# # Cross Validation spliting data

# %% [markdown]
# ## Getting training-valdata

# %%
def splitingDataFold(df):
    df = df.copy()
    #spliting data test- training
    x = df.iloc[:, 1:34]
    y = df.iloc[:, 0]
    #Scale the data
    scaler = StandardScaler()
    x = scaler.fit_transform(x)
    kf = KFold(n_splits=5, random_state = None, shuffle=True)
    #xTrain,xTest,yTrain,yTest = train_test_split(x,y,train_size=0.8,shuffle=True,random_state=42)
    #dataframe not numpy array - try differetn appoarch
    xTrain=[]
    yTrain=[]
    yTest=[]
    xTest=[]
    for train_index, test_index in kf.split(x):
        print("TRAIN:", train_index, "TEST:", test_index)
        xTrain.append(x[train_index])
        #print(x[train_index])
        xTest.append(x[test_index])
        yTrain.append(y[train_index])
        yTest.append(y[test_index])
    
    return xTrain,xTest,yTrain,yTest

# %%
dfCopy = df_Elite.copy()
dfCopy
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueKills  blueDeaths  \
# 0            0               32                   5         10          15
# 1            1               49                   6         10          14
# 2            1               26                   2         17          10
# 3            1              106                   8         10           8
# 4            1               31                  10         22           7
# ...        ...              ...                 ...        ...         ...
# 8631         1               24                   7          6           7
# 8632         1               20                   8         15           9
# 8633         1               26                   4         17          16
# 8634         1               27                   9          7          13
# 8635         0               20                   4          8          13
#
#       blueAssists  blueEliteMonsters  blueDragons  blueHeraldsBarons  \
# 0              15                  0            0                  0
# 1               6                  1            1                  0
# 2              24                  2            1                  1
# 3              18                  2            1                  1
# 4              24                  3            2                  1
# ...           ...                ...          ...                ...
# 8631            8                  1            1                  0
# 8632           13                  1            1                  0
# 8633           21                  3            2                  1
# 8634           11                  1            1                  0
# 8635            4                  1            0                  1
#
#       blueTowersDestroyed  ...  redTowersDestroyed  redTotalGold  \
# 0                       1  ...                   1         26016
# 1                       0  ...                   1         25835
# 2                       0  ...                   1         23499
# 3                       0  ...                   0         21625
# 4                       2  ...                   0         21954
# ...                   ...  ...                 ...           ...
# 8631                    0  ...                   0         23558
# 8632                    1  ...                   1         24741
# 8633                    1  ...                   0         25491
# 8634                    0  ...                   1         25270
# 8635                    0  ...                   1         28009
#
#       redTotalDamageToChampions  redAvgLevel  redTotalMinionsKilled  \
# 0                         22836          8.4                    279
# 1                         20998          8.6                    301
# 2                         25089          8.6                    268
# 3                         21831          8.4                    297
# 4                         19995          8.4                    293
# ...                         ...          ...                    ...
# 8631                      19954          8.6                    340
# 8632                      23249          8.8                    317
# 8633                      31258          8.6                    246
# 8634                      21193          9.0                    297
# 8635                      24678          9.6                    387
#
#       redTotalJungleMinionsKilled  blue/redAvgLevel  \
# 0                              69           1.00000
# 1                              77           0.97674
# 2                              80           1.06977
# 3                              76           1.02381
# 4                              79           1.11905
# ...                           ...               ...
# 8631                          100           1.00000
# 8632                           79           1.00000
# 8633                           62           1.00000
# 8634                           68           0.97778
# 8635                           87           0.91667
#
#       blue/redTotalDamageToChampions  red/blueKills  blueAvgLevel/redAvgLevel
# 0                            1.09940        0.66667                   1.00000
# 1                            0.92795        0.71429                   0.97674
# 2                            1.20710        1.70000                   1.06977
# 3                            1.09880        1.25000                   1.02381
# 4                            1.73458        3.14286                   1.11905
# ...                              ...            ...                       ...
# 8631                         0.80946        0.85714                   1.00000
# 8632                         0.96520        1.66667                   1.00000
# 8633                         1.12246        1.06250                   1.00000
# 8634                         1.01321        0.53846                   0.97778
# 8635                         0.65694        0.61538                   0.91667
#
# [8636 rows x 34 columns]

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)
dfCopy=clean_dataset(dfCopy)
dfCopy
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueKills  blueDeaths  \
# 0          0.0             32.0                 5.0       10.0        15.0
# 1          1.0             49.0                 6.0       10.0        14.0
# 2          1.0             26.0                 2.0       17.0        10.0
# 3          1.0            106.0                 8.0       10.0         8.0
# 4          1.0             31.0                10.0       22.0         7.0
# ...        ...              ...                 ...        ...         ...
# 8631       1.0             24.0                 7.0        6.0         7.0
# 8632       1.0             20.0                 8.0       15.0         9.0
# 8633       1.0             26.0                 4.0       17.0        16.0
# 8634       1.0             27.0                 9.0        7.0        13.0
# 8635       0.0             20.0                 4.0        8.0        13.0
#
#       blueAssists  blueEliteMonsters  blueDragons  blueHeraldsBarons  \
# 0            15.0                0.0          0.0                0.0
# 1             6.0                1.0          1.0                0.0
# 2            24.0                2.0          1.0                1.0
# 3            18.0                2.0          1.0                1.0
# 4            24.0                3.0          2.0                1.0
# ...           ...                ...          ...                ...
# 8631          8.0                1.0          1.0                0.0
# 8632         13.0                1.0          1.0                0.0
# 8633         21.0                3.0          2.0                1.0
# 8634         11.0                1.0          1.0                0.0
# 8635          4.0                1.0          0.0                1.0
#
#       blueTowersDestroyed  ...  redTowersDestroyed  redTotalGold  \
# 0                     1.0  ...                 1.0       26016.0
# 1                     0.0  ...                 1.0       25835.0
# 2                     0.0  ...                 1.0       23499.0
# 3                     0.0  ...                 0.0       21625.0
# 4                     2.0  ...                 0.0       21954.0
# ...                   ...  ...                 ...           ...
# 8631                  0.0  ...                 0.0       23558.0
# 8632                  1.0  ...                 1.0       24741.0
# 8633                  1.0  ...                 0.0       25491.0
# 8634                  0.0  ...                 1.0       25270.0
# 8635                  0.0  ...                 1.0       28009.0
#
#       redTotalDamageToChampions  redAvgLevel  redTotalMinionsKilled  \
# 0                       22836.0          8.4                  279.0
# 1                       20998.0          8.6                  301.0
# 2                       25089.0          8.6                  268.0
# 3                       21831.0          8.4                  297.0
# 4                       19995.0          8.4                  293.0
# ...                         ...          ...                    ...
# 8631                    19954.0          8.6                  340.0
# 8632                    23249.0          8.8                  317.0
# 8633                    31258.0          8.6                  246.0
# 8634                    21193.0          9.0                  297.0
# 8635                    24678.0          9.6                  387.0
#
#       redTotalJungleMinionsKilled  blue/redAvgLevel  \
# 0                            69.0           1.00000
# 1                            77.0           0.97674
# 2                            80.0           1.06977
# 3                            76.0           1.02381
# 4                            79.0           1.11905
# ...                           ...               ...
# 8631                        100.0           1.00000
# 8632                         79.0           1.00000
# 8633                         62.0           1.00000
# 8634                         68.0           0.97778
# 8635                         87.0           0.91667
#
#       blue/redTotalDamageToChampions  red/blueKills  blueAvgLevel/redAvgLevel
# 0                            1.09940        0.66667                   1.00000
# 1                            0.92795        0.71429                   0.97674
# 2                            1.20710        1.70000                   1.06977
# 3                            1.09880        1.25000                   1.02381
# 4                            1.73458        3.14286                   1.11905
# ...                              ...            ...                       ...
# 8631                         0.80946        0.85714                   1.00000
# 8632                         0.96520        1.66667                   1.00000
# 8633                         1.12246        1.06250                   1.00000
# 8634                         1.01321        0.53846                   0.97778
# 8635                         0.65694        0.61538                   0.91667
#
# [8631 rows x 34 columns]

# %%
xTrain_Elite,xTest_Elite,yTrain_Elite,yTest_Elite = splitingDataFold(dfCopy)
print ("Training set: {} samples".format(len(xTrain_Elite[0])))
print ("Test set: {} samples".format(len(xTest_Elite[0])))
# Out:
# TRAIN: [   0    2    3 ... 8625 8629 8630] TEST: [   1    7    9 ... 8626 8627 8628]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21244/3995009733.py in <module>
# ----> 1 xTrain_Elite,xTest_Elite,yTrain_Elite,yTest_Elite = splitingDataFold(dfCopy)
#       2 print ("Training set: {} samples".format(len(xTrain_Elite[0])))
#       3 print ("Test set: {} samples".format(len(xTest_Elite[0])))
#
# ~\AppData\Local\Temp/ipykernel_21244/3686147031.py in splitingDataFold(df)
#      19         #print(x[train_index])
#      20         xTest.append(x[test_index])
# ---> 21         yTrain.append(y[train_index])
#      22         yTest.append(y[test_index])
#      23
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\series.py in __getitem__(self, key)
#     964             return self._get_values(key)
#     965
# --> 966         return self._get_with(key)
#     967
#     968     def _get_with(self, key):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\series.py in _get_with(self, key)
#     999             #  (i.e. self.iloc) or label-based (i.e. self.loc)
#    1000             if not self.index._should_fallback_to_positional():
# -> 1001                 return self.loc[key]
#    1002             else:
#    1003                 return self.iloc[key]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: '[2787, 4839, 6413, 6648] not in index'

# %%
xTrain_Skilled,xTest_Skilled,yTrain_Skilled,yTest_Skilled = splitingDataFold(df_Skilled)
print ("Training set: {} samples".format(len(xTrain_Skilled[0])))
print ("Test set: {} samples".format(len(xTest_Skilled[0])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12720/33466734.py in <module>
# ----> 1 xTrain_Skilled,xTest_Skilled,yTrain_Skilled,yTest_Skilled = splitingDataFold(df_Skilled)
#       2 print ("Training set: {} samples".format(len(xTrain_Skilled[0])))
#       3 print ("Test set: {} samples".format(len(xTest_Skilled[0])))
#
# ~\AppData\Local\Temp/ipykernel_12720/3686147031.py in splitingDataFold(df)
#       6     #Scale the data
#       7     scaler = StandardScaler()
# ----> 8     x = scaler.fit_transform(x)
#       9     kf = KFold(n_splits=5, random_state = None, shuffle=True)
#      10     #xTrain,xTest,yTrain,yTest = train_test_split(x,y,train_size=0.8,shuffle=True,random_state=42)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     839         """
#     840         first_call = not hasattr(self, "n_samples_seen_")
# --> 841         X = self._validate_data(
#     842             X,
#     843             accept_sparse=("csr", "csc"),
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains infinity or a value too large for dtype('float64').

# %%
xTrain_Average,xTest_Average,yTrain_Average,yTest_Average = splitingDataFold(df_Average)
print ("Training set: {} samples".format(len(xTrain_Average[0])))
print ("Test set: {} samples".format(len(xTest_Average[0])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21352/2234361702.py in <module>
# ----> 1 xTrain_Average,xTest_Average,yTrain_Average,yTest_Average = splitingDataFold(df_Average)
#       2 print ("Training set: {} samples".format(len(xTrain_Average[0])))
#       3 print ("Test set: {} samples".format(len(xTest_Average[0])))
#
# ~\AppData\Local\Temp/ipykernel_21352/3686147031.py in splitingDataFold(df)
#       6     #Scale the data
#       7     scaler = StandardScaler()
# ----> 8     x = scaler.fit_transform(x)
#       9     kf = KFold(n_splits=5, random_state = None, shuffle=True)
#      10     #xTrain,xTest,yTrain,yTest = train_test_split(x,y,train_size=0.8,shuffle=True,random_state=42)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     839         """
#     840         first_call = not hasattr(self, "n_samples_seen_")
# --> 841         X = self._validate_data(
#     842             X,
#     843             accept_sparse=("csr", "csc"),
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains infinity or a value too large for dtype('float64').

# %% [markdown]
# ### Training logistic regression

# %%
def trainingModelLogisticRegression(x_train,y_train,reg,sol):
    lr = LogisticRegression(penalty=reg, solver=sol,max_iter=1000)
    lr.fit(x_train,y_train)
    return lr

# %% [markdown]
# #### l1 regulization

# %%
trainedEliteLrL1=[]
trainedAverageLrL1=[]
trainedSkilledLrL1=[]
for i in range(0,5):
    trainedEliteLrL1.append(trainingModelLogisticRegression(xTrain_Elite[i],yTrain_Elite[i],'l1','saga'))
    trainedAverageLrL1.append(trainingModelLogisticRegression(xTrain_Average[i],yTrain_Average[i],'l1','saga'))
    trainedSkilledLrL1.append(trainingModelLogisticRegression(xTrain_Skilled[i],yTrain_Skilled[i],'l1','saga'))

# %% [markdown]
# #### l2 regulization

# %%
trainedEliteLrL2=[]
trainedAverageLrL2=[]
trainedSkilledLrL2=[]
for i in range(0,5):
    trainedEliteLrL2.append(trainingModelLogisticRegression(xTrain_Elite[i],yTrain_Elite[i],'l2','saga'))
    trainedAverageLrL2.append(trainingModelLogisticRegression(xTrain_Average[i],yTrain_Average[i],'l2','saga'))
    trainedSkilledLrL2.append(trainingModelLogisticRegression(xTrain_Skilled[i],yTrain_Skilled[i],'l2','saga'))

# %% [markdown]
# #### No Regulaztion

# %%
trainedEliteLrNone=[]
trainedAverageLrNone=[]
trainedSkilledLrNone=[]
for i in range(0,5):
    trainedEliteLrNone.append(trainingModelLogisticRegression(xTrain_Elite[i],yTrain_Elite[i],'none','saga'))
    trainedAverageLrNone.append(trainingModelLogisticRegression(xTrain_Average[i],yTrain_Average[i],'none','saga'))
    trainedSkilledLrNone.append(trainingModelLogisticRegression(xTrain_Skilled[i],yTrain_Skilled[i],'none','saga'))

# %% [markdown]
# ### Tesing Model

# %%
def testingLr(lr,x_test,y_test):
    name = ['','fold 1','fold 2','fold 3','fold 4','fold 5','Average']
    acc = ['Accuracy']
    pre = ['Precision']
    re = ['Recall']
    f1 = ['F1 Score']
    sumacc=0
    sumf1=0
    sumpre=0
    sumre= 0

    for i in range(0,5):
        
        testEliteLr = lr[i].predict(x_test[i])
        testEliteLr_prob = lr[i].predict_proba(x_test[i])
        
        accs= accuracy_score(y_test[i], testEliteLr)
        pres= precision_score(y_test[i], testEliteLr)
        res = recall_score(y_test[i], testEliteLr)
        f1s = f1_score(y_test[i], testEliteLr)
        
        sumacc =sumacc+accs
        sumpre =sumpre+pres
        sumre = sumre +res
        sumf1 =sumf1+f1s
        
        acc.append(' {:.5f}'.format(accs))
        pre.append(' {:.5f}'.format(pres))
        re.append(' {:.5f}'.format(res))
        f1.append(' {:.5f}'.format(f1s))
        
    acc.append(' {:.5f}'.format(sumacc/5))
    pre.append(' {:.5f}'.format(sumpre/5))
    re.append(' {:.5f}'.format(sumre/5))
    f1.append(' {:.5f}'.format(sumf1/5))
    
    table=[]
    table.append(name)
    table.append(acc)
    table.append(pre)
    table.append(re)
    table.append(f1)
    
    print(tabulate(table))

# %% [markdown]
# ### Coefficients

# %%
def coefficientsLr(model):
    coefficients = np.hstack((model.intercept_,model.coef_[0]))
    name = ['blueWardsPlaced','blueWardsDestroyed','blueKills','blueDeaths','blueAssists','blueEliteMonsters','blueDragons','blueHeraldsBarons','blueTowersDestroyed','blueTotalGold','blueTotalDamageToChampions','blueAvgLevel','blueTotalMinionsKilled','blueTotalJungleMinionsKilled','blueGoldDiff','redWardsPlaced','redWardsDestroyed','redKills','redDeaths','redAssists','redEliteMonsters','redDragons','redHeraldsBarons','redTowersDestroyed','redTotalGold','redTotalDamageToChampions','redAvgLevel','redTotalMinionsKilled','redTotalJungleMinionsKilled','blue/redAvgLevel','blue/redTotalDamageToChampions','red/blueKills','blueAvgLevel/redAvgLevel']
    return name,coefficients

# %% [markdown]
# ### Elite Data

# %% [markdown]
# #### Testing data

# %%
#No regularization
testingLr(trainedEliteLrNone,xTest_Elite,yTest_Elite)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.78125  0.78344  0.78286  0.76665  0.78691  0.78022
# Precision  0.77315  0.80556  0.78413  0.76058  0.79157  0.78300
# Recall     0.78588  0.78463  0.77958  0.75420  0.78060  0.77698
# F1 Score   0.77946  0.79496  0.78185  0.75738  0.78605  0.77994
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L1 regularization
testingLr(trainedEliteLrL1,xTest_Elite,yTest_Elite)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.78125  0.78402  0.78228  0.76723  0.78633  0.78022
# Precision  0.77315  0.80577  0.78322  0.76087  0.79132  0.78287
# Recall     0.78588  0.78571  0.77958  0.75540  0.77945  0.77720
# F1 Score   0.77946  0.79562  0.78140  0.75812  0.78534  0.77999
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L2 regularization
testingLr(trainedEliteLrL2,xTest_Elite,yTest_Elite)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.78125  0.78344  0.78286  0.76665  0.78691  0.78022
# Precision  0.77315  0.80556  0.78413  0.76058  0.79157  0.78300
# Recall     0.78588  0.78463  0.77958  0.75420  0.78060  0.77698
# F1 Score   0.77946  0.79496  0.78185  0.75738  0.78605  0.77994
# ---------  -------  -------  -------  -------  -------  -------

# %% [markdown]
# #### Training data

# %%
#No regularization
testingLr(trainedEliteLrNone,xTrain_Elite,yTrain_Elite)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.78228  0.78231  0.78072  0.78767  0.77942  0.78248
# Precision  0.78675  0.78275  0.78350  0.79197  0.78500  0.78599
# Recall     0.77998  0.77403  0.77922  0.78812  0.77233  0.77874
# F1 Score   0.78335  0.77837  0.78135  0.79004  0.77862  0.78234
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L1 regularization
testingLr(trainedEliteLrL1,xTrain_Elite,yTrain_Elite)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.78170  0.78304  0.78087  0.78781  0.77927  0.78254
# Precision  0.78600  0.78341  0.78340  0.79219  0.78494  0.78599
# Recall     0.77969  0.77491  0.77979  0.78812  0.77205  0.77891
# F1 Score   0.78283  0.77914  0.78159  0.79015  0.77844  0.78243
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L2 regularization
testingLr(trainedEliteLrL2,xTrain_Elite,yTrain_Elite)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.78228  0.78246  0.78072  0.78781  0.77927  0.78251
# Precision  0.78658  0.78298  0.78350  0.79219  0.78494  0.78604
# Recall     0.78026  0.77403  0.77922  0.78812  0.77205  0.77874
# F1 Score   0.78341  0.77848  0.78135  0.79015  0.77844  0.78237
# ---------  -------  -------  -------  -------  -------  -------

# %% [markdown]
# #### Coefficient

# %%
#Take fold 2 as L1 regularization has highest accuracy
#L1 regularization
name,coef = coefficientsLr(trainedEliteLrL1[1])
df = pd.DataFrame(data={'variable': ['Intercept'] + name, 'coefficient': coef})
df = df.sort_values(by='coefficient')
print(df.to_markdown())
# Out:
# |    | variable                     |   coefficient |
# |---:|:-----------------------------|--------------:|
# | 30 | redGoldDiff                  |   -0.750889   |
# | 22 | redDragons                   |   -0.204057   |
# | 27 | redAvgLevel                  |   -0.110121   |
# | 28 | redTotalMinionsKilled        |   -0.0824082  |
# |  4 | blueDeaths                   |   -0.0553598  |
# | 18 | redKills                     |   -0.0553598  |
# |  9 | blueTowersDestroyed          |   -0.0304338  |
# |  1 | blueWardsPlaced              |   -0.0238405  |
# | 26 | redTotalDamageToChampions    |   -0.018866   |
# | 24 | redTowersDestroyed           |   -0.0140906  |
# |  0 | Intercept                    |   -0.0128633  |
# | 29 | redTotalJungleMinionsKilled  |   -0.00912491 |
# | 20 | redAssists                   |   -0.00590365 |
# |  8 | blueHeraldsBarons            |    0          |
# | 21 | redSkilledMonsters           |    0          |
# | 25 | redTotalGold                 |    0          |
# | 23 | redHeraldsBarons             |    0          |
# | 13 | blueTotalMinionsKilled       |    0.00328903 |
# | 16 | redWardsPlaced               |    0.0054659  |
# | 10 | blueTotalGold                |    0.00968755 |
# |  6 | blueSkilledMonsters          |    0.0459386  |
# |  3 | blueKills                    |    0.0494996  |
# | 19 | redDeaths                    |    0.0494996  |
# |  5 | blueAssists                  |    0.0496545  |
# | 17 | redWardsDestroyed            |    0.0523521  |
# | 11 | blueTotalDamageToChampions   |    0.062109   |
# |  2 | blueWardsDestroyed           |    0.0722823  |
# | 14 | blueTotalJungleMinionsKilled |    0.0752956  |
# |  7 | blueDragons                  |    0.0761878  |
# | 12 | blueAvgLevel                 |    0.198504   |
# | 15 | blueGoldDiff                 |    0.750889   |

# %% [markdown]
# ### Skilled Data

# %% [markdown]
# #### Testing data

# %%
#No regularization
testingLr(trainedSkilledLrNone,xTest_Skilled,yTest_Skilled)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76079  0.74736  0.76850  0.76911  0.75699  0.76055
# Precision  0.75948  0.74700  0.76423  0.77083  0.75249  0.75881
# Recall     0.76548  0.74402  0.76731  0.75847  0.74944  0.75694
# F1 Score   0.76247  0.74551  0.76577  0.76460  0.75096  0.75786
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L1 regularization
testingLr(trainedSkilledLrL1,xTest_Skilled,yTest_Skilled)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76079  0.74758  0.76894  0.76889  0.75655  0.76055
# Precision  0.75948  0.74733  0.76468  0.77048  0.75226  0.75885
# Recall     0.76548  0.74402  0.76775  0.75847  0.74854  0.75685
# F1 Score   0.76247  0.74567  0.76621  0.76443  0.75040  0.75784
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L2 regularization
testingLr(trainedSkilledLrL2,xTest_Skilled,yTest_Skilled)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76079  0.74758  0.76850  0.76911  0.75677  0.76055
# Precision  0.75948  0.74733  0.76423  0.77083  0.75238  0.75885
# Recall     0.76548  0.74402  0.76731  0.75847  0.74899  0.75685
# F1 Score   0.76247  0.74567  0.76577  0.76460  0.75068  0.75784
# ---------  -------  -------  -------  -------  -------  -------

# %% [markdown]
# #### Training data

# %%
#No regularization
testingLr(trainedSkilledLrNone,xTrain_Skilled,yTrain_Skilled)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76126  0.76424  0.75939  0.75913  0.76271  0.76134
# Precision  0.75905  0.76176  0.75742  0.75647  0.76106  0.75915
# Recall     0.75625  0.76133  0.75683  0.75748  0.76114  0.75861
# F1 Score   0.75765  0.76154  0.75713  0.75697  0.76110  0.75888
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L1 regularization
testingLr(trainedSkilledLrL1,xTrain_Skilled,yTrain_Skilled)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76143  0.76418  0.75933  0.75874  0.76265  0.76127
# Precision  0.75918  0.76150  0.75734  0.75605  0.76092  0.75900
# Recall     0.75647  0.76167  0.75683  0.75714  0.76126  0.75867
# F1 Score   0.75783  0.76158  0.75709  0.75660  0.76109  0.75884
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L2 regularization
testingLr(trainedSkilledLrL2,xTrain_Skilled,yTrain_Skilled)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76132  0.76418  0.75933  0.75913  0.76265  0.76132
# Precision  0.75913  0.76167  0.75734  0.75647  0.76098  0.75912
# Recall     0.75625  0.76133  0.75683  0.75748  0.76114  0.75861
# F1 Score   0.75769  0.76150  0.75709  0.75697  0.76106  0.75886
# ---------  -------  -------  -------  -------  -------  -------

# %% [markdown]
# #### Coefficients

# %%
#Take fold 4 as L1 regularization has highest accuracy
#L1 regularization
name,coef = coefficientsLr(trainedSkilledLrL1[3])
df = pd.DataFrame(data={'variable': ['Intercept'] + name, 'coefficient': coef})
df = df.sort_values(by='coefficient')
print(df.to_markdown())
# Out:
# |    | variable                     |   coefficient |
# |---:|:-----------------------------|--------------:|
# | 30 | redGoldDiff                  |   -0.559223   |
# | 27 | redAvgLevel                  |   -0.187826   |
# | 26 | redTotalDamageToChampions    |   -0.160397   |
# | 22 | redDragons                   |   -0.13499    |
# | 25 | redTotalGold                 |   -0.112752   |
# | 29 | redTotalJungleMinionsKilled  |   -0.0551606  |
# | 17 | redWardsDestroyed            |   -0.0463468  |
# |  0 | Intercept                    |   -0.0330008  |
# |  9 | blueTowersDestroyed          |   -0.0328128  |
# | 21 | redSkilledMonsters           |   -0.0041404  |
# | 28 | redTotalMinionsKilled        |   -0.00332008 |
# | 16 | redWardsPlaced               |   -0.00188297 |
# |  8 | blueHeraldsBarons            |    0          |
# | 10 | blueTotalGold                |    0          |
# | 23 | redHeraldsBarons             |    0          |
# |  1 | blueWardsPlaced              |    0.00124159 |
# | 18 | redKills                     |    0.00220202 |
# |  4 | blueDeaths                   |    0.00220202 |
# | 20 | redAssists                   |    0.00285928 |
# | 24 | redTowersDestroyed           |    0.0142329  |
# |  2 | blueWardsDestroyed           |    0.0165188  |
# |  5 | blueAssists                  |    0.0251245  |
# |  3 | blueKills                    |    0.0422789  |
# | 19 | redDeaths                    |    0.0422789  |
# | 14 | blueTotalJungleMinionsKilled |    0.0488793  |
# |  6 | blueSkilledMonsters          |    0.0539467  |
# | 13 | blueTotalMinionsKilled       |    0.057197   |
# | 11 | blueTotalDamageToChampions   |    0.118932   |
# |  7 | blueDragons                  |    0.146366   |
# | 12 | blueAvgLevel                 |    0.158296   |
# | 15 | blueGoldDiff                 |    0.559223   |

# %% [markdown]
# ### Average Data

# %% [markdown]
# #### Testing data

# %%
#No regularization
testingLr(trainedAverageLrNone,xTest_Average,yTest_Average)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76683  0.75223  0.76727  0.76324  0.76227  0.76237
# Precision  0.76470  0.75503  0.76518  0.76715  0.76759  0.76393
# Recall     0.77538  0.75115  0.77467  0.76567  0.75311  0.76400
# F1 Score   0.77000  0.75308  0.76989  0.76641  0.76028  0.76393
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L1 regularization
testingLr(trainedAverageLrL1,xTest_Average,yTest_Average)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76683  0.75231  0.76709  0.76342  0.76209  0.76235
# Precision  0.76470  0.75525  0.76491  0.76732  0.76740  0.76392
# Recall     0.77538  0.75097  0.77467  0.76584  0.75293  0.76396
# F1 Score   0.77000  0.75311  0.76976  0.76658  0.76010  0.76391
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L2 regularization
testingLr(trainedAverageLrL2,xTest_Average,yTest_Average)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76683  0.75223  0.76727  0.76324  0.76227  0.76237
# Precision  0.76470  0.75512  0.76518  0.76715  0.76759  0.76394
# Recall     0.77538  0.75097  0.77467  0.76567  0.75311  0.76396
# F1 Score   0.77000  0.75304  0.76989  0.76641  0.76028  0.76392
# ---------  -------  -------  -------  -------  -------  -------

# %% [markdown]
# #### Training data

# %%
#No regularization
testingLr(trainedAverageLrNone,xTrain_Average,yTrain_Average)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76170  0.76568  0.76125  0.76266  0.76299  0.76286
# Precision  0.76371  0.76725  0.76296  0.76408  0.76474  0.76455
# Recall     0.76249  0.76735  0.76290  0.76324  0.76521  0.76424
# F1 Score   0.76310  0.76730  0.76293  0.76366  0.76498  0.76439
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L1 regularization
testingLr(trainedAverageLrL1,xTrain_Average,yTrain_Average)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76172  0.76566  0.76123  0.76268  0.76299  0.76286
# Precision  0.76372  0.76719  0.76288  0.76409  0.76474  0.76453
# Recall     0.76254  0.76740  0.76298  0.76328  0.76521  0.76428
# F1 Score   0.76313  0.76730  0.76293  0.76369  0.76498  0.76440
# ---------  -------  -------  -------  -------  -------  -------

# %%
#L2 regularization
testingLr(trainedAverageLrL2,xTrain_Average,yTrain_Average)
# Out:
# ---------  -------  -------  -------  -------  -------  -------
#            fold 1   fold 2   fold 3   fold 4   fold 5   Average
# Accuracy   0.76172  0.76570  0.76123  0.76264  0.76302  0.76286
# Precision  0.76372  0.76724  0.76293  0.76407  0.76475  0.76454
# Recall     0.76254  0.76744  0.76290  0.76319  0.76526  0.76426
# F1 Score   0.76313  0.76734  0.76291  0.76363  0.76500  0.76440
# ---------  -------  -------  -------  -------  -------  -------

# %% [markdown]
# #### Coefficients

# %%
#Take fold 3 as L1 regularization has highest accuracy
#L1 regularization
name,coef = coefficientsLr(trainedAverageLrL1[2])
df = pd.DataFrame(data={'variable': ['Intercept'] + name, 'coefficient': coef})
df = df.sort_values(by='coefficient')
print(df.to_markdown())
# Out:
# |    | variable                     |   coefficient |
# |---:|:-----------------------------|--------------:|
# | 30 | redGoldDiff                  |  -0.661659    |
# | 22 | redDragons                   |  -0.15202     |
# | 27 | redAvgLevel                  |  -0.104642    |
# | 26 | redTotalDamageToChampions    |  -0.0979488   |
# | 28 | redTotalMinionsKilled        |  -0.0758968   |
# |  4 | blueDeaths                   |  -0.0584897   |
# | 18 | redKills                     |  -0.0584897   |
# | 21 | redSkilledMonsters           |  -0.0551592   |
# |  9 | blueTowersDestroyed          |  -0.0550993   |
# |  5 | blueAssists                  |  -0.054939    |
# | 29 | redTotalJungleMinionsKilled  |  -0.0348236   |
# |  2 | blueWardsDestroyed           |  -0.0110719   |
# |  1 | blueWardsPlaced              |  -0.00410845  |
# | 16 | redWardsPlaced               |  -0.000197734 |
# |  8 | blueHeraldsBarons            |   0           |
# | 23 | redHeraldsBarons             |   0           |
# | 25 | redTotalGold                 |   0           |
# | 17 | redWardsDestroyed            |   0.0038141   |
# | 10 | blueTotalGold                |   0.0131195   |
# |  3 | blueKills                    |   0.01489     |
# | 19 | redDeaths                    |   0.01489     |
# | 14 | blueTotalJungleMinionsKilled |   0.022338    |
# |  6 | blueSkilledMonsters          |   0.0271034   |
# |  0 | Intercept                    |   0.0272422   |
# | 24 | redTowersDestroyed           |   0.0516778   |
# | 13 | blueTotalMinionsKilled       |   0.0558541   |
# | 20 | redAssists                   |   0.0603481   |
# | 12 | blueAvgLevel                 |   0.101233    |
# | 11 | blueTotalDamageToChampions   |   0.132199    |
# |  7 | blueDragons                  |   0.192448    |
# | 15 | blueGoldDiff                 |   0.661659    |
